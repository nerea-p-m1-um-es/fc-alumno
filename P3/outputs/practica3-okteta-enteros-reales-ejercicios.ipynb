# %% [markdown]
# # Ejercicios - Práctica 3: Decodificación de Ficheros con Okteta. Enteros, reales y caracteres

# %% [markdown]
# **EJERCICIO**

# %% [markdown]
# * Interpretar con la herramienta `okteta` el contenido del fichero `ejercicio_N.bin`, **donde `N` será un número entre 0 y 9 que deberás elegir de acuerdo a la última cifra de tu DNI**. Dichos ficheros están disponibles en el AV.
#
# Cada uno de estos ficheros `ejercicio_N.bin` contiene a modo de "cabecera", en los primeros 160 bytes del fichero, un conjunto de caracteres en los cuales se codifica de manera textual los datos contenidos en dicho fichero a partir del desplazamiento 160 decimal (0xA0), además del esquema de almacenamiento utilizado (*little/big endian*). Así, por ejemplo, el fichero cuya cabecera se muestra en la siguiente imagen **tendría codificados a partir del desplazamiento 0xA0 los siguientes 7 datos, en formato *big endian***:
#
# 1. Un número real de simple precisión (*float*)
# 2. Una cadena de caracteres
# 3. Un número real de doble precisión (*double*)
# 4. Un número entero con signo de 32 bits (*int*)
# 5. Un número entero con signo de 64 bits (*long*)
# 6. Un número entero sin signo de 16 bits (*unsigned short*)
# 7. Un número entero con signo de 8 bits (*byte*)
#
# ![image.png](attachment:877538dc-f437-4449-96d7-2d4bfe497934.png)

# %% [markdown]
# <br>
# <font size="4">  <span style="color: red;"><b>RECUERDA:</b> Esta cabecera es un ejemplo; el fichero que te corresponde según tu DNI tendrá estos u otros tipos de datos, probablemente en otro orden diferente al mostrado por este ejemplo.</span></font>

# %% [markdown]
# Para cada uno de los datos que hay codificados en el fichero `ejercicio_N.bin` que te corresponda según tu DNI, debes indicar en las siguientes celdas, en el mismo orden en que aparecen en el fichero, lo siguiente:
# - Tipo de dato y tamaño
# - Desplazamiento donde comienza y acaba el dato (ambos inclusive, en hexadecimal)
# - Los bytes que codifican el dato en el fichero (en hexadecimal)
# - La ristra de bits que codifican el dato, una vez que están en el orden correcto (en hexadecimal)
# - El valor (información) codificada por dicho dato (el número entero o real representado, en decimal, o la cadena de caracteres representada)

# %% [markdown]
# <br>
# <font size="5">  <span style="color: green;">DATO 1</span></font>

# %% [markdown]
# - Tipo de dato y tamaño en bytes:

# %% [markdown]
# RESPUESTA:

# %% [markdown]
# - Desplazamiento inicial:

# %% [markdown]
# RESPUESTA:

# %% [markdown]
# - Desplazamiento final:

# %% [markdown]
# RESPUESTA:

# %% [markdown]
# - Codificación en el fichero:

# %% [markdown]
# RESPUESTA:

# %% [markdown]
# - Ristra de bits:

# %% [markdown]
# RESPUESTA:

# %% [markdown]
# - Información representada (valor codificado):

# %% [markdown]
# RESPUESTA:

# %% [markdown]
# <br>
# <font size="5">  <span style="color: green;">DATO 2</span></font>

# %% [markdown]
# - Tipo de dato y tamaño en bytes:

# %% [markdown]
# RESPUESTA:

# %% [markdown]
# - Desplazamiento inicial:

# %% [markdown]
# RESPUESTA:

# %% [markdown]
# - Desplazamiento final:

# %% [markdown]
# RESPUESTA:

# %% [markdown]
# - Codificación en el fichero:

# %% [markdown]
# RESPUESTA:

# %% [markdown]
# - Ristra de bits:

# %% [markdown]
# RESPUESTA:

# %% [markdown]
# - Información representada (valor codificado):

# %% [markdown]
# RESPUESTA:

# %% [markdown]
# <br>
# <font size="5">  <span style="color: green;">DATO 3</span></font>

# %% [markdown]
# - Tipo de dato y tamaño en bytes:

# %% [markdown]
# RESPUESTA:

# %% [markdown]
# - Desplazamiento inicial:

# %% [markdown]
# RESPUESTA:

# %% [markdown]
# - Desplazamiento final:

# %% [markdown]
# RESPUESTA:

# %% [markdown]
# - Codificación en el fichero:

# %% [markdown]
# RESPUESTA:

# %% [markdown]
# - Ristra de bits:

# %% [markdown]
# RESPUESTA:

# %% [markdown]
# - Información representada (valor codificado):

# %% [markdown]
# RESPUESTA:

# %% [markdown]
# <br>
# <font size="5">  <span style="color: green;">DATO 4</span></font>

# %% [markdown]
# - Tipo de dato y tamaño en bytes:

# %% [markdown]
# RESPUESTA:

# %% [markdown]
# - Desplazamiento inicial:

# %% [markdown]
# RESPUESTA:

# %% [markdown]
# - Desplazamiento final:

# %% [markdown]
# RESPUESTA:

# %% [markdown]
# - Codificación en el fichero:

# %% [markdown]
# RESPUESTA:

# %% [markdown]
# - Ristra de bits:

# %% [markdown]
# RESPUESTA:

# %% [markdown]
# - Información representada (valor codificado):

# %% [markdown]
# RESPUESTA:

# %% [markdown]
# <br>
# <font size="5">  <span style="color: green;">DATO 5</span></font>

# %% [markdown]
# - Tipo de dato y tamaño en bytes:

# %% [markdown]
# RESPUESTA:

# %% [markdown]
# - Desplazamiento inicial:

# %% [markdown]
# RESPUESTA:

# %% [markdown]
# - Desplazamiento final:

# %% [markdown]
# RESPUESTA:

# %% [markdown]
# - Codificación en el fichero:

# %% [markdown]
# RESPUESTA:

# %% [markdown]
# - Ristra de bits:

# %% [markdown]
# RESPUESTA:

# %% [markdown]
# - Información representada (valor codificado):

# %% [markdown]
# RESPUESTA:

# %% [markdown]
# <br>
# <font size="5">  <span style="color: green;">DATO 6</span></font>

# %% [markdown]
# - Tipo de dato y tamaño en bytes:

# %% [markdown]
# RESPUESTA:

# %% [markdown]
# - Desplazamiento inicial:

# %% [markdown]
# RESPUESTA:

# %% [markdown]
# - Desplazamiento final:

# %% [markdown]
# RESPUESTA:

# %% [markdown]
# - Codificación en el fichero:

# %% [markdown]
# RESPUESTA:

# %% [markdown]
# - Ristra de bits:

# %% [markdown]
# RESPUESTA:

# %% [markdown]
# - Información representada (valor codificado):

# %% [markdown]
# RESPUESTA:

# %% [markdown]
# <br>
# <font size="5">  <span style="color: green;">DATO 7</span></font>

# %% [markdown]
# - Tipo de dato y tamaño en bytes:

# %% [markdown]
# RESPUESTA:

# %% [markdown]
# - Desplazamiento inicial:

# %% [markdown]
# RESPUESTA:

# %% [markdown]
# - Desplazamiento final:

# %% [markdown]
# RESPUESTA:

# %% [markdown]
# - Codificación en el fichero:

# %% [markdown]
# RESPUESTA:

# %% [markdown]
# - Ristra de bits:

# %% [markdown]
# RESPUESTA:

# %% [markdown]
# - Información representada (valor codificado):

# %% [markdown]
# RESPUESTA:

# %% [markdown]
# **EJERCICIO**

# %% [markdown]
# - Modificar los contenidos del fichero de manera que almacenen, en los mismos desplazamientos de los datos originales y manteniendo el mismo tipo de dato y tamaño, los siguientes valores:
#     - La misma cadena de caracteres, pero todo en mayúsculas.
#     - El resultado de multiplicar el número real de simple precisión original por 16.
#     - El resultado de dividir el número real de doble precisión original entre 2.
#     - El número entero de igual magnitud pero signo opuesto.
#     - El número entero corto con mayor valor absoluto posible y mismo signo que el original.
#     - El mismo número entero largo, pero almacenado en el orden de bytes opuesto.
#     - El byte que almacenaría el resultado de desplazar el valor original a la derecha 2 bits.

# %% [markdown]
# 1. **Cadena de caracteres**:

# %% [markdown]
# - Codificación en el fichero:

# %% [markdown]
# RESPUESTA:

# %% [markdown]
# 2. **Número real de simple precisión (*float*)**:

# %% [markdown]
# - Codificación en el fichero:

# %% [markdown]
# RESPUESTA:

# %% [markdown]
# 3. **Número real en doble precisión (*double*)**:

# %% [markdown]
# - Codificación en el fichero:

# %% [markdown]
# RESPUESTA:

# %% [markdown]
# 3. **Número entero con signo de 32 bits (*int*)**:

# %% [markdown]
# - Codificación en el fichero:

# %% [markdown]
# RESPUESTA:

# %% [markdown]
# 5. **Número entero con signo de 16 bits (*short int*)**:

# %% [markdown]
# - Codificación en el fichero:

# %% [markdown]
# RESPUESTA:

# %% [markdown]
# 6. **Número entero de 64 bits (*long*)**:

# %% [markdown]
# - Codificación en el fichero:

# %% [markdown]
# RESPUESTA:

# %% [markdown]
# 7. **Número entero de 8 bits (*byte*)**:

# %% [markdown]
# - Codificación en el fichero:

# %% [markdown]
# RESPUESTA:

# %% [markdown]
# **FINALMENTE, SUBE A TU REPOSITORIO BITÁCORA DEL ALUMNO EL FICHERO MODIFICADO**. Debe estar ubicado en el mismo directorio que este *notebook*: `fc-alumno/P3`

# %% [markdown]
# **EJERCICIO**

# %%
mkdir p3-ejercicio && cd p3-ejercicio

# %% [markdown]
# - Ejecuta la siguiente celda para crear un fichero llamado `mojibake.txt`.

# %%
echo "La palabra "mojibake" en japonés se escribe así:" > mojibake.txt

# %% [markdown]
# - Tras guardar el fichero y cerrar el editor de texto, muestra su contenido con el comando `cat`:

# %%
cat mojibake.txt
# Out:
# La palabra mojibake en japonés se escribe así:

# %%
# Cuenta los caracteres de mojibake.txt
# Out:
# 47 mojibake.txt

# %% [markdown]
# PREGUNTA: ¿Cuántos caracteres tiene el fichero?

# %% [markdown]
# RESPUESTA:

# %% [markdown]
# - Ahora ejecuta el comando `ls` con la opción adecuada para averiguar su tamaño.

# %%
# Lista el fichero mojibake de forma que se muestre su tamaño
# Out:
# -rw-r--r-- 1 jupyter-rtitos-um-es jupyter-rtitos-um-es 49 sep 10 16:06 mojibake.txt

# %% [markdown]
# PREGUNTA: ¿Qué tamaño tiene el fichero? (en bytes)

# %% [markdown]
# RESPUESTA:

# %%
cat mojibake.txt
# Out:
# La palabra mojibake en japonés se escribe así:

# %% [markdown]
# PREGUNTA: A la vista de la información anterior (número de bytes vs número de caracteres), y de los caracteres que contiene el fichero, ¿qué codificación de caracteres se está utilizando? Justifica la respuesta.
#
# RESPUESTA:

# %% [markdown]
# - Ejecuta la siguiente celda para mostrar los bytes que contiene el fichero "en crudo" (hexadecimal) y su interpretación como caracteres. (*NOTA: `hexdump` es similar a `okteta` pero su interfaz es de línea de comandos en vez de gráfica.*)

# %%
hexdump -C mojibake.txt
# Out:
# 00000000  4c 61 20 70 61 6c 61 62  72 61 20 6d 6f 6a 69 62  |La palabra mojib|
# 00000010  61 6b 65 20 65 6e 20 6a  61 70 6f 6e c3 a9 73 20  |ake en japon..s |
# 00000020  73 65 20 65 73 63 72 69  62 65 20 61 73 c3 ad 3a  |se escribe as..:|
# 00000030  0a                                                |.|
# 00000031

# %% [markdown]
# PREGUNTA: ¿Qué byte o bytes corresponden al carácter `í` en dicha codificación de caracteres?
#
# RESPUESTA (hexadecimal):

# %% [markdown]
# RESPUESTA:

# %% [markdown]
# Ahora abre de nuevo el fichero con el editor de textos, elige "Guardar como", ponle como nombre `mojibake-latin9.txt` y selecciona la codificación de caracteres  `ISO-8859-15 (Occidental)`.

# %%
# Esta celda emula el cambio de codificación sin abrir el editor de texto
iconv --from-code=utf8 --to-code=iso-8859-15 mojibake.txt -o mojibake-latin9.txt
# Out:
# iconv: no se admite la conversión de utf8
# iconv: pruebe 'iconv -l' para obtener la lista de codificaciones admitidas
# : 1

# %%
iconv --help
# Out:
# Modo de empleo: iconv [OPCIÓN...] [-f CODIFICACIÓN] [-t CODIFICACIÓN] [FICHEROENTRADA...]
# o bien: iconv -l
# Convierte texto de una codificación a otra.
# Opciones para controlar el formato de entrada y de salida:
#   -f CODIFICACIÓN, --from-code=CODIFICACIÓN
#                               codificación de la entrada
#   -t CODIFICACIÓN, --to-code=CONDIFICACIÓN
#                               codificación de la salida
# Opciones para controlar los problemas de conversión:
#   -c                          descarta los caracteres no convertibles
#   --unicode-subst=CADENADEFORMATO
#                               sustitución para los caracteres Unicode no convertibles
#   --byte-subst=CADENADEFORMATO  sustitución para los bytes no convertibles
#   --widechar-subst=CADENADEFORMATO
#                               sustitución para los caracteres anchos no convertibles
# Opciones para controlar la salida de error:
# ...

# %% [markdown]
# - Ejecuta la siguiente celda para mostrar la codificación que utiliza *bash* en tu sistema en función de la configuración regional (idioma, etc.):

# %%
echo $LANG
# Out:
# es_ES.UTF-8

# %% [markdown]
# PREGUNTA: ¿Qué configuración regional (de idioma) y codificación de caracteres está utilizando en tu sistema?

# %% [markdown]
# RESPUESTA:

# %% [markdown]
# - Ahora, muestra el contenido de `mojibake-latin9.txt` con el comando `cat`:

# %%
cat mojibake-latin9.txt
# Out:
# cat: mojibake-latin9.txt: No existe el archivo o el directorio
# : 1

# %% [markdown]
# PREGUNTA: ¿Qué ocurre? Razona la respuesta basándote en la configuración actual del sistema.
#
# RESPUESTA:

# %% [markdown]
# - Ejecuta la siguiente celda para añadir los símbolos que codifican la palabra *mojibake* en japonés (  文字化け  ) al fichero `mojibake-japanese.txt`.

# %%
echo -n "文字化け" > mojibake-japanese.txt

# %%
# Usa `file" para ver el tipo y codificación del fichero
# Out:
# mojibake-japanese.txt: Unicode text, UTF-8 text, with no line terminators

# %% [markdown]
# - Repite el comando `wc` del ejercicio anterior con la opción adecuada para este nuevo fichero, para contar cuántos caracteres (símbolos) contiene.

# %%
# Out:
# 4 mojibake-japanese.txt

# %% [markdown]
# RESPUESTA:

# %% [markdown]
# - Averigua el tamaño del fichero con la opción adecuada de `ls`.

# %%
# Out:
# -rw-r--r-- 1 jupyter-rtitos-um-es jupyter-rtitos-um-es 12 sep 10 16:06 mojibake-japanese.txt

# %% [markdown]
# RESPUESTA:

# %% [markdown]
# - ¿En cuántos bytes se codifica cada uno de los símbolos que componen "mojibake" en japonés (文字化け)? Razona la respuesta a partir de las diferencias con la codificación de los caracteres del `ASCII` y `latin9` en el esquema de codificación que se está usando en el sistema.

# %% [markdown]
# RESPUESTA:

# %% [markdown]
# - Por último, haz un volcado del contenido del fichero con `hexdump`, ejecutando la siguiente celda. A la vista de la información mostrado, ¿cuál es la codificación del símbolo `文`?

# %%
hexdump -C mojibake-japanese.txt
# Out:
# 00000000  e6 96 87 e5 ad 97 e5 8c  96 e3 81 91              |............|
# 0000000c

# %% [markdown]
# RESPUESTA:

# %%
# Eliminamos los ficheros generados por este cuaderno
cd ..
rm -rf p3-ejercicio

# %% [markdown]
# **FIN DEL CUADERNO** (*no borres esta celda*)
#
# @@@@ practica3-okteta-enteros-reales-ejercicios.ipynb @@@@
